# %% [markdown]
# # Report: act_report

# %% [markdown]
# ## Introduction:
# This analysis explores data from the WeRateDogs Twitter account, focusing on tweet content, user engagement, and machine learning predictions about dog breeds. The dataset was cleaned, merged, and enhanced to create a master DataFrame for deeper insights.
#
# ## Insights:
# <ul>
#   <li><strong>Dog State Popularity and Ratings</strong>:
#     Among the classified dog "states," the 'puppo' state emerged as the highest-rated and most favorited category, while the 'pupper' state recorded the lowest average rating and engagement. This suggests that the community reacts more positively to certain dog states.
#
#   </li>
#   <br>
#   <li><strong>Breed Frequency</strong>:
#     The most commonly predicted dog breed is the golden retriever, followed by other familiar breeds. These predictions are based on the model’s primary label (p1) and confidence levels, and may reflect real-world breed popularity.
#   </li>
#   <img src = "https://media.posterlounge.com/img/products/610000/609815/609815_poster.jpg" alt="golden retriever" style ="width: 300px; height: 500px;">
#   <li><strong>Most Common Dog Names</strong>:
#     The names "Charlie," "Cooper," and "Lucy" are the most frequently occurring in the dataset, indicating their popularity among dog owners in the sample tweets.
#   </li>
#   <br>
#   <li><strong>Rating vs. Favorite Count</strong>:
#     Engagement sharply increases with ratings between 10 and 15. A bar plot comparing ratings out of 10 to the number of favorites shows a clear positive trend, particularly from ratings of 10/10 up to the exaggerated 15/10, commonly used by the WeRateDogs account.
#   </li>
# </ul>

# %% [markdown]
# ## Visualization:

# %%
from IPython.display import Image
Image('plot.png')

# %% [markdown]
# ## Conclusion of the act report:
# The analysis shows that dog states like "puppo," higher confidence in breed prediction, and elevated ratings all contribute to increased engagement. Popular breeds and names also align with higher favorites, suggesting that familiarity and clear imagery play key roles in audience appeal. The results can be used to increase the popularity of tweets to get more activity!
